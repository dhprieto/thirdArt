# %%
# data manipulation
import pandas as pd
import numpy as np
from readFiles import fullRead

# data viz
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns

# apply some cool styling
plt.style.use("ggplot")
rcParams['figure.figsize'] = (12, 6)

# %%
df_anthro = pd.read_csv("data/chronicAnthropometricCardiovascularData.csv", sep=";", decimal=",")
df_anthro
# Out:
#      numVol  Peso inicial  Peso final  Delta Peso  Talla  IMC Inicial  \
# 0         1          75.2        75.0        -0.2   1.64         28.0
# 1         2          70.2        69.8        -0.4   1.60         27.4
# 2         3          80.4        76.2        -4.2   1.73         26.9
# 3         4          77.8        80.3         2.5   1.61         30.0
# 4         5          70.4        70.3        -0.1   1.68         24.9
# ..      ...           ...         ...         ...    ...          ...
# 131     142          91.1        90.3        -0.8   1.84         26.9
# 132     143         108.1       108.0        -0.1   1.78         34.1
# 133     144          99.8       101.4         1.6   1.72         33.7
# 134     145          96.1        93.9        -2.2   1.69         33.6
# 135     146          71.9        70.7        -1.2   1.68         25.5
#
#      IMC Final  Delta IMC  Grasa inicial  Grasa final  Delta Grasa  \
# ...

# %%
#EDA

df_UF.columns
df_UF.shape
df_UF.describe()
df_UF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 250 entries, 0 to 249
# Data columns (total 24 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   numVol     250 non-null    int64
#  1   E          250 non-null    float64
#  2   EG.1       250 non-null    float64
#  3   E.S        250 non-null    float64
#  4   Total.E    250 non-null    float64
#  5   HE         250 non-null    float64
#  6   HE.G       250 non-null    float64
#  7   HE.GG      250 non-null    float64
#  8   Total.HE   250 non-null    float64
#  9   N          250 non-null    float64
#  10  N.G        250 non-null    float64
#  11  N.GG       250 non-null    float64
#  12  N.S        250 non-null    float64
#  13  Total.N    250 non-null    float64
#  14  Sweetener  250 non-null    object
#  15  Time       250 non-null    object
#  16  Sex        250 non-null    object
#  17  Weight     250 non-null    float64
#  18  BMI        250 non-null    float64
# ...

# %%
df_UF = fullRead("data/urineFlav_ord.csv")
df_UF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 250 entries, 0 to 249
# Data columns (total 24 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   numVol     250 non-null    int64
#  1   E          250 non-null    float64
#  2   EG.1       250 non-null    float64
#  3   E.S        250 non-null    float64
#  4   Total.E    250 non-null    float64
#  5   HE         250 non-null    float64
#  6   HE.G       250 non-null    float64
#  7   HE.GG      250 non-null    float64
#  8   Total.HE   250 non-null    float64
#  9   N          250 non-null    float64
#  10  N.G        250 non-null    float64
#  11  N.GG       250 non-null    float64
#  12  N.S        250 non-null    float64
#  13  Total.N    250 non-null    float64
#  14  Sweetener  250 non-null    object
#  15  Time       250 non-null    object
#  16  Sex        250 non-null    object
#  17  Weight     250 non-null    float64
#  18  BMI        250 non-null    float64
# ...

# %%
df_UA = fullRead("data/urineAnt_ord.csv")
np.isnan(df_UA)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 df_UA = fullRead("data/urineAnt_ord.csv")
# ----> 2 np.isnan(df_UA)
#
# File c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:2032, in NDFrame.__array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#    2029 def __array_ufunc__(
#    2030     self, ufunc: np.ufunc, method: str, *inputs: Any, **kwargs: Any
#    2031 ):
# -> 2032     return arraylike.array_ufunc(self, ufunc, method, *inputs, **kwargs)
#
# File c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\arraylike.py:372, in array_ufunc(self, ufunc, method, *inputs, **kwargs)
#     367 if method == "__call__" and not kwargs:
#     368     # for np.<ufunc>(..) calls
#     369     # kwargs cannot necessarily be handled block-by-block, so only
#     370     # take this path if there are no kwargs
# ...

# %%
df_PA = fullRead("data/plasmAnt_ord.csv")
df_PA
# Out:
#      numVol        CA      CA.G      CA.S  Total.CA     DHPAA   DHPAA.G  \
# 0         1  0.036145  0.117857  0.241935  0.173442  0.273438  0.098739
# 1         1  0.602410  0.046429  0.629032  0.311653  0.105938  0.105042
# 2         2  0.000000  0.067857  0.000000  0.032520  0.253125  0.132353
# 3         2  0.000000  0.200000  0.387097  0.216802  0.267813  0.090336
# 4         3  0.204819  0.000000  0.161290  0.108401  0.169687  0.049370
# ..      ...       ...       ...       ...       ...       ...       ...
# 239     140  0.204819  0.014286  0.080645  0.105691  0.285000  0.000000
# 240     141  0.301205  0.010714  0.338710  0.168022  0.495000  0.274160
# 241     141  0.120482  0.067857  0.193548  0.146341  0.274375  0.047269
# 242     142  0.277108  0.007143  0.161290  0.130081  0.190625  0.177521
# 243     142  0.421687  0.075000  0.177419  0.216802  0.199063  0.101891
#
#      DHPAA.GG  DHPAA.GS  DHPAA.SS  ...  Sweetener     Time    Sex  Weight  \
# ...

# %%
df_PF = fullRead("data/plasmFlav_ord.csv")
df_PF
# Out:
#      numVol         E  E.S  Total.E      HE.G       N.G Sweetener     Time  \
# 0         1  0.444444  0.1    0.625  0.003582  0.055300        ST  Initial
# 1         1  0.333333  0.0    0.000  0.000398  0.031666        ST    Final
# 2         2  0.222222  0.1    0.375  0.000199  0.015973        ST  Initial
# 3         2  0.333333  0.3    0.000  0.001592  0.015226        ST    Final
# 4         3  0.666667  0.0    0.000  0.012338  0.024349        ST    Final
# ..      ...       ...  ...      ...       ...       ...       ...      ...
# 239     140  0.111111  0.0    0.000  0.000199  0.007784        SA  Initial
# 240     141  0.222222  0.0    0.000  0.001393  0.126604        SA    Final
# 241     141  0.000000  0.0    0.000  0.000597  0.041848        SA  Initial
# 242     142  0.333333  0.0    0.000  0.000398  0.025470        SA  Initial
# 243     142  0.444444  0.1    0.000  0.001393  0.072892        SA    Final
#
#        Sex Weight   BMI   Fat  CVRI  Bpmin  Bpmax  Frec
# ...
